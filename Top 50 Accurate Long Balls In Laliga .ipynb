# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\user\Desktop\laliga2023_34\player_accurate_long_balls.xlsx")

# %%
df
# Out:
#      Rank                   Player                 Team  \
# 0       1               Toni Kroos          Real Madrid
# 1       2             Sergio Ramos              Sevilla
# 2       3             Aleix Garcia               Girona
# 3       4         Alejandro Catena              Osasuna
# 4       5            Omar Alderete               Getafe
# 5       6              Luka Modric          Real Madrid
# 6       7          Florian Lejeune       Rayo Vallecano
# 7       8            Mario Hermoso  AtlÃ©tico de Madrid
# 8       9           Inigo Martinez            Barcelona
# 9      10          Rodrigo De Paul  AtlÃ©tico de Madrid
# 10     11                     Koke  AtlÃ©tico de Madrid
# 11     12               Luis Milla               Getafe
# 12     13             Victor Chust               CÃ¡diz
# 13     14              Pau Cubarsi            Barcelona
# 14     15            Daniel Parejo           Villarreal
# 15     16             Renato Tapia        Celta de Vigo
# ...

# %%
pd.set_option('display.max_rows',320)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315 entries, 0 to 314
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Rank                        315 non-null    int64
#  1   Player                      315 non-null    object
#  2   Team                        315 non-null    object
#  3   Accurate Long Balls per 90  315 non-null    float64
#  4   Successful Long Balls (%)   315 non-null    float64
#  5   Minutes                     315 non-null    int64
#  6   Matches                     315 non-null    int64
#  7   Country                     315 non-null    object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 19.8+ KB

# %%
df.describe()
# Out:
#              Rank  Accurate Long Balls per 90  Successful Long Balls (%)  \
# count  315.000000                  315.000000                 315.000000
# mean   157.952381                    1.821587                  50.186349
# std     91.031112                    1.278576                  14.826845
# min      1.000000                    0.000000                  14.300000
# 25%     79.500000                    0.900000                  39.950000
# 50%    158.000000                    1.600000                  50.000000
# 75%    236.500000                    2.600000                  58.400000
# max    315.000000                    9.800000                 100.000000
#
#            Minutes     Matches
# count   315.000000  315.000000
# mean   1883.574603   29.114286
# std     670.785752    5.175852
# min     193.000000   19.000000
# 25%    1421.000000   25.000000
# 50%    1852.000000   30.000000
# 75%    2454.000000   33.000000
# max    3328.000000   38.000000

# %%
df[df['Player'].str.contains('Toni Kroos')]
# Out:
#    Rank      Player         Team  Accurate Long Balls per 90  \
# 0     1  Toni Kroos  Real Madrid                         9.8
#
#    Successful Long Balls (%)  Minutes  Matches Country
# 0                       85.9     2130       33     GER

# %%
df[df['Successful Long Balls (%)']== 100 ]
# Out:
#      Rank           Player            Team  Accurate Long Balls per 90  \
# 266   267   Radamel Falcao  Rayo Vallecano                         0.5
# 297   298     AndrÃ© Silva   Real Sociedad                         0.2
# 298   298  Roman Yaremchuk     Valencia CF                         0.2
# 307   308     Artem Dovbyk          Girona                         0.1
#
#      Successful Long Balls (%)  Minutes  Matches Country
# 266                      100.0      391       22     COL
# 297                      100.0      730       19     POR
# 298                      100.0      926       25     UKR
# 307                      100.0     2605       36     UKR

# %%
df[df['Minutes'] == 3328]
# Out:
#    Rank           Player            Team  Accurate Long Balls per 90  \
# 6     7  Florian Lejeune  Rayo Vallecano                         5.1
#
#    Successful Long Balls (%)  Minutes  Matches Country
# 6                       44.4     3328       37     FRA

# %%
df[df['Successful Long Balls (%)'] == 14.3]
# Out:
#      Rank          Player         Team  Accurate Long Balls per 90  \
# 286   287  Jesus VÃ¡zquez  Valencia CF                         0.4
#
#      Successful Long Balls (%)  Minutes  Matches Country
# 286                       14.3      705       20     ESP

# %%
df.isnull().sum()
# Out:
# Rank                          0
# Player                        0
# Team                          0
# Accurate Long Balls per 90    0
# Successful Long Balls (%)     0
# Minutes                       0
# Matches                       0
# Country                       0
# dtype: int64

# %%
df.nunique()
# Out:
# Rank                          301
# Player                        314
# Team                           20
# Accurate Long Balls per 90     51
# Successful Long Balls (%)     203
# Minutes                       301
# Matches                        20
# Country                        46
# dtype: int64

# %%
df
# Out:
#      Rank                   Player                 Team  \
# 0       1               Toni Kroos          Real Madrid
# 1       2             Sergio Ramos              Sevilla
# 2       3             Aleix Garcia               Girona
# 3       4         Alejandro Catena              Osasuna
# 4       5            Omar Alderete               Getafe
# 5       6              Luka Modric          Real Madrid
# 6       7          Florian Lejeune       Rayo Vallecano
# 7       8            Mario Hermoso  AtlÃ©tico de Madrid
# 8       9           Inigo Martinez            Barcelona
# 9      10          Rodrigo De Paul  AtlÃ©tico de Madrid
# 10     11                     Koke  AtlÃ©tico de Madrid
# 11     12               Luis Milla               Getafe
# 12     13             Victor Chust               CÃ¡diz
# 13     14              Pau Cubarsi            Barcelona
# 14     15            Daniel Parejo           Villarreal
# 15     16             Renato Tapia        Celta de Vigo
# ...

# %%
df['Team']=df['Team'].str.replace('AtlÃ©tico de Madrid','Atletico de Madrid')

# %%
df['Team']=df['Team'].str.replace('CÃ¡diz','Cadiz CF')

# %%
df['Team']=df['Team'].str.replace('AlavÃ©s','Deportivo Alaves')

# %%
df['Team']=df['Team'].str.replace('AlmerÃ­a','UD Almeria')

# %%
df['Team']
# Out:
# 0             Real Madrid
# 1                 Sevilla
# 2                  Girona
# 3                 Osasuna
# 4                  Getafe
# 5             Real Madrid
# 6          Rayo Vallecano
# 7      Atletico de Madrid
# 8               Barcelona
# 9      Atletico de Madrid
# 10     Atletico de Madrid
# 11                 Getafe
# 12               Cadiz CF
# 13              Barcelona
# 14             Villarreal
# 15          Celta de Vigo
# 16          Celta de Vigo
# 17               Cadiz CF
# 18            Valencia CF
# 19                Osasuna
# 20             Granada CF
# 21       Deportivo Alaves
# 22          Athletic Club
# 23     Atletico de Madrid
# 24               Cadiz CF
# 25            Valencia CF
# 26     Atletico de Madrid
# 27             Real Betis
# 28                 Girona
# 29             Villarreal
# 30                Sevilla
# 31          Real Sociedad
# 32         Rayo Vallecano
# 33             UD Almeria
# 34          Real Sociedad
# ...

# %%
df
# Out:
#      Rank                   Player                Team  \
# 0       1               Toni Kroos         Real Madrid
# 1       2             Sergio Ramos             Sevilla
# 2       3             Aleix Garcia              Girona
# 3       4         Alejandro Catena             Osasuna
# 4       5            Omar Alderete              Getafe
# 5       6              Luka Modric         Real Madrid
# 6       7          Florian Lejeune      Rayo Vallecano
# 7       8            Mario Hermoso  Atletico de Madrid
# 8       9           Inigo Martinez           Barcelona
# 9      10          Rodrigo De Paul  Atletico de Madrid
# 10     11                     Koke  Atletico de Madrid
# 11     12               Luis Milla              Getafe
# 12     13             Victor Chust            Cadiz CF
# 13     14              Pau Cubarsi           Barcelona
# 14     15            Daniel Parejo          Villarreal
# 15     16             Renato Tapia       Celta de Vigo
# ...

# %%
df['Player']=df['Player'].str.replace('Yeray Ãlvarez','Yeray Alvarez')

# %%
df['Player']=df['Player'].str.replace('JosÃ© GimÃ©nez','Jose Gimenez')

# %%
df['Player']=df['Player'].str.replace('RubÃ©n Alcaraz','Ruben Alcaraz')

# %%
df['Player']=df['Player'].str.replace('Jules KoundÃ©','Jules Kounde')

# %%
df['Player']=df['Player'].str.replace('RubÃ©n Duarte','Ruben Duarte')

# %%
df['Player']=df['Player'].str.replace('Ezequiel Ãvila','Ezequiel Avila')

# %%
df2=df.head(50)

# %%
df2
# Out:
#     Rank            Player                Team  Accurate Long Balls per 90  \
# 0      1        Toni Kroos         Real Madrid                         9.8
# 1      2      Sergio Ramos             Sevilla                         6.3
# 2      3      Aleix Garcia              Girona                         6.1
# 3      4  Alejandro Catena             Osasuna                         5.5
# 4      5     Omar Alderete              Getafe                         5.5
# 5      6       Luka Modric         Real Madrid                         5.3
# 6      7   Florian Lejeune      Rayo Vallecano                         5.1
# 7      8     Mario Hermoso  Atletico de Madrid                         4.8
# 8      9    Inigo Martinez           Barcelona                         4.7
# 9     10   Rodrigo De Paul  Atletico de Madrid                         4.3
# 10    11              Koke  Atletico de Madrid                         4.3
# ...

# %%
df2.to_csv(r'C:\Users\user\Desktop\osikhe\Top 50 accurate long balls in laliga.csv')
